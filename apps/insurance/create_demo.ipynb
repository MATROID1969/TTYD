# %%
import pandas as pd

INPUT_CSV = "data/data.csv"
OUTPUT_CSV = "data/data_demo.csv"

REFERENCE_DATE_IN_DATA = "2025-02-13"
TARGET_TODAY = "2026-01-21"

# betöltés
df = pd.read_csv(INPUT_CSV, sep=";")

# eltolás kiszámítása
ref_date = pd.to_datetime(REFERENCE_DATE_IN_DATA)
target_date = pd.to_datetime(TARGET_TODAY)

delta = target_date - ref_date
delta_days = delta.days

print(f"Dátumeltolás: {delta_days} nap")

# dátum oszlopok felismerése (ISO formátum miatt biztonságos)
date_columns = []
for col in df.columns:
    try:
        parsed = pd.to_datetime(df[col], format="%Y-%m-%d", errors="raise")
        date_columns.append(col)
    except Exception:
        continue

print("Eltolt dátumoszlopok:", date_columns)

# eltolás alkalmazása
for col in date_columns:
    df[col] = pd.to_datetime(df[col]) + pd.to_timedelta(delta_days, unit="D")
    df[col] = df[col].dt.strftime("%Y-%m-%d")

# mentés
df.to_csv(OUTPUT_CSV, index=False, sep = ";", encoding="utf-8")
df.sample(frac=0.002).to_csv("data/data_demo_sample.csv", index=False, sep = ";", encoding="utf-8")

print("Demo adatbázis elkészült:", OUTPUT_CSV)
# Out:
# Dátumeltolás: 342 nap
# Eltolt dátumoszlopok: ['Dijrendezes_datuma', 'Szerzodeskotes_datuma', 'Dijfizetes_kezdete', 'Kockazatviselés_kezdete', 'Kockazatviselés_vege', 'Szerzodes_lejarat_datuma', 'Halasztott_kockazatviseles_kezdete', 'Halasztott_dijfizetes_kezdete', 'Szerzodes_evfordulo', 'Honap', 'Honap_str']
# Demo adatbázis elkészült: data/data_demo.csv
